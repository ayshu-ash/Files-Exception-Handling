# %% [markdown]
# # **Files, exceptional handling, logging and memory management Questions**

# %% [markdown]
# 1. What is the difference between interpreted and compiled languages?
#   * Interpreted Language
#
#     - Code is executed line by line by an interpreter.
#
#     - Slower in execution but easier to debug.
#
#     - Example: Python, JavaScript.
#
#    * Compiled Language
#
#     - Code is first translated into machine code (binary) by a compiler, then executed.
#
#     - Faster in execution but debugging is harder.
#
#     - Example: C, C++.
#
# ---------
#
# 2. What is exception handling in Python?
#
#     An exception is an event that occurs during programme execution that disrupts the regular flow of execution (for example, when a key is not found in a dictionary). A Python object that reflects an error is known as an exception.
#
#     In Python, an exception is an object derived from the BaseException class that includes information about a method error occurrence. Below are some standard exceptions:
#
# * FileNotFoundException
#
# * ImportError
#
# * RuntimeError
#
# * TypeError
#
# ----------
#
# 3. What is the purpose of the finally block in exception handling?
#
#   * The finally block in Python is used to execute code no matter what happens in the try and except blocks.
#
#   * It always runs whether an exception occurs or not.
#
#   * Commonly used for cleanup tasks like closing files, releasing memory, or disconnecting from databases.
#
# ------------
#
# 4. What is logging in Python?
#
#   * Logging in Python is the process of recording messages about a program's execution.
#
#   * It helps track events, errors, and warnings while the program runs.
#
#   * More powerful than print() because it supports different levels (DEBUG, INFO, WARNING, ERROR, CRITICAL) and can save logs to files for future analysis.
#
# ------------
#
# 5. What is the significance of the __del__ method in Python?
#
#   The __del__ method in Python is known as a destructor. It is called automatically when an object is about to be destroyed or goes out of scope. It is mainly used to perform cleanup tasks like closing files, releasing memory, or freeing resources before the object is deleted.
#
# ----------------------
#
# 6. What is the difference between import and from ... import in Python?
#
#   * import module
#
#     - Imports the entire module.
#
#     - To use functions/variables, you must write the module name as a prefix.
#
#               Example:
#
#               import math
#               print(math.sqrt(16))   # module name required
#
#   * from module import name
#
#     - Imports specific functions, classes, or variables from a module.
#
#     - You can use them directly without the module prefix.
#
#                Example:
#
#                from math import sqrt
#                print(sqrt(16))   # directly used
#
# -------------------------
#
# 7. How can you handle multiple exceptions in Python?
#
#    In Python, you can handle multiple exceptions in two ways:
#
#    * Using multiple except blocks :- each block handles a different type of error.
#
#             try:
#               x = int("abc")
#             except ValueError:
#               print("Value Error occurred")
#             except TypeError:
#               print("Type Error occurred")
#
#   * Using a single except block with a tuple of exceptions – handles multiple errors together.
#
#               try:
#                 x = int("abc")
#               except (ValueError, TypeError) as e:
#                 print("Error:", e)
#
# -----------------------
#
# 8. What is the purpose of the with statement when handling files in Python?
#
#    * The with statement is used to handle files more safely and efficiently.
#
#    * It automatically opens and closes the file, even if an exception occurs.
#
#    * This prevents resource leaks and ensures that the file is properly closed.
#
#    * It makes the code cleaner and easier to read.
#
# ------------------------
#
# 9. What is the difference between multithreading and multiprocessing?
#
#   * Independence:-
#
#      Multiprocessing: In multiprocessing, each process runs independently with its own memory space. Processes do not share memory by default, and communication between them requires explicit mechanisms such as inter-process communication (IPC).
#
#      Multithreading: In multithreading, multiple threads share the same memory space within a single process. Threads can communicate more directly by accessing shared data.
#
#    * Communication:-
#
#      Multiprocessing: Communication between processes is typically achieved through IPC mechanisms like message passing, shared memory, or file-based communication.
#
#      Multithreading: Threads can communicate more easily by sharing data directly, as they have access to the same memory space.
#
#   * Fault Isolation:-
#
#     Multiprocessing: Processes are more isolated, providing better fault isolation. If one process crashes, it does not necessarily affect others.
#
#     Multithreading: Threads within the same process share the same memory space, making them more susceptible to issues such as data corruption or unintended interactions.
#
#    * Resource Utilization:-
#
#     Multiprocessing: Can take advantage of multiple CPU cores, as each process can run on a separate core. Suitable for CPU-bound tasks.
#
#     Multithreading: Suitable for I/O-bound tasks or tasks where parallelism can be achieved within a single process.
#
#    * Concurrency:-
#
#     Multiprocessing: Involves concurrent execution of multiple processes, each with its own program counter and resources.
#
#     Multithreading: Involves concurrent execution of multiple threads within the same process, sharing the same program counter.
#
# ---------------------------
#
# 10. What are the advantages of using logging in a program?
#
#    * Tracks Program Execution:- Helps monitor the flow of the program and know which parts ran successfully.
#
#    * Error and Debugging Aid:- Records errors, warnings, and important events for troubleshooting.
#
#    * Different Log Levels:- Supports DEBUG, INFO, WARNING, ERROR, and CRITICAL for better control.
#
#    * Persistent Records:- Logs can be saved to files for future analysis, unlike print() statements.
#
#    * Improves Maintenance:- Makes it easier to maintain and understand the program behavior over time.
#
# --------------------
#
# 11. What is memory management in Python?
#
#    * Memory management in Python is the process of allocating and freeing memory for objects efficiently.
#
#    * Python automatically handles memory using reference counting and a garbage collector.
#
#    * It ensures that memory occupied by objects no longer in use is released, preventing memory leaks.
#
#    * This helps programs run smoothly without running out of memory.
#
# -------------------
#
# 12. What are the basic steps involved in exception handling in Python?
#
#    i) try – Write code that may cause an error.
#
#    ii)except – Handle the error if it occurs.
#
#    iii)else (optional) – Run if no exception occurs.
#
#    iv) finally (optional) – Execute cleanup code, runs always
#
# -------------------
#
# 13. Why is memory management important in Python?
#
#    Memory management is important to ensure that Python programs use memory efficiently and safely.
#
#    * It prevents memory leaks, which can slow down or crash programs.
#
#    * Frees memory used by objects no longer needed, keeping programs stable and fast.
#
#    * Helps Python handle large data or multiple objects without running out of memory.
#
# ------------------
#
# 14. What is the role of try and except in exception handling?
#
#    When an exception occurs, Python stops the program and generates an exception message. Handling exceptions is strongly advised. Risky code is questionable code that may throw an exception.
#
#    To handle exceptions, we must utilise the try and except blocks. Define dangerous code that can throw an exception inside the try block and related handling code inside the except block.
#
#                 Syntax:
#                 try:
#                     statements in try block
#                 except:
#                     executed when exception occurred in try block
#
# -----------------------
#
# 15. How does Python's garbage collection system work?
#
#    Python automatically manages memory using a garbage collector.
#
#    * It primarily uses reference counting: each object keeps track of how many references point to it. When the count reaches zero, memory is freed.
#
#    * It also uses a cyclic garbage collector to detect and clean up objects that reference each other in a cycle.
#
#    * This process helps prevent memory leaks and ensures efficient memory usage.
#
# -----------------
#
# 16. What is the purpose of the else block in exception handling?
#
#   * The else block runs only if no exception occurs in the try block.
#
#   * It is used for code that should execute only when the try block is successful.
#
#   * Helps separate normal execution logic from error-handling code, making programs cleaner.
#
# -------------------
#
# 17. What are the common logging levels in Python?
#
#   Python's logging module provides different levels to indicate the severity of events:
#
#    * DEBUG - Detailed information, mainly for debugging purposes.
#
#    * INFO - General information about program execution.
#
#    * WARNING - Indicates a potential problem or unexpected event.
#
#    * ERROR - Serious problem that caused part of the program to fail.
#
#    * CRITICAL - Very serious error that may stop the program from running.
#
# ---------------------
#
# 18. What is the difference between os.fork() and multiprocessing in Python?
#
#   * os.fork()
#
#    - Creates a child process by duplicating the current process.
#
#    - Works only on Unix/Linux systems.
#
#    - Less flexible, lower-level control over processes.
#
#   * multiprocessing module
#
#    - Provides a high-level interface to create and manage multiple processes.
#
#    - Cross-platform (works on Windows, Linux, macOS).
#
#    - Supports sharing data between processes and easier process management.
#
# ---------------------
#
# 19. What is the importance of closing a file in Python?
#
#     * Releases resources:- Frees system resources (memory, file handles).
#
#     * Saves data:- Ensures all buffered data is written to the file.
#
#     * Prevents corruption:- Avoids data loss or file corruption.
#
#     * Good practice:- Keeps code clean and avoids errors like "too many open files".
#
# --------------------
#
# 20. What is the difference between file.read() and file.readline() in Python?
#
#     * file.read():-
#
#      - Reads the entire file content (or a specified number of characters if given).
#
#      - Returns the content as one string.
#
#              Example:
#
#              f = open("test.txt", "r")
#              data = f.read()
#              print(data)   # prints whole file
#              f.close()
#
#     * file.readline():-
#
#       - Reads only one line from the file at a time.
#
#       - Each call moves to the next line.
#
#       - Returns the line as a string (including the newline \n at the end, if present).
#
#              Example:
#
#              f = open("test.txt", "r")
#              line1 = f.readline()
#              line2 = f.readline()
#              print(line1)   # prints first line
#              print(line2)   # prints second line
#              f.close()
#
# ----------------------------
#
# 21. What is the logging module in Python used for?
#
#   The logging module in Python is used to record (log) messages from a program, such as errors, warnings, or information, to help in debugging and monitoring.
#
#    Uses:
#
#    * Provides different log levels (DEBUG, INFO, WARNING, ERROR, CRITICAL).
#
#    * Helps track the flow of a program.
#
#    * Logs can be stored in a file or shown in the console.
#
#    * Useful for finding and fixing issues without using print statements.
#
# ---------------
#
# 22. What is the os module in Python used for in file handling?
#
#     The os module in Python provides functions to interact with the operating system. In file handling, it is mainly used to manage files and directories.
#
#     Uses of os module in file handling:
#
#      * File operations:- remove or rename files (os.remove(), os.rename()).
#
#      * Directory operations:- create, delete, and navigate directories (os.mkdir(), os.rmdir(), os.chdir()).
#
#      * Path operations:- work with file paths (os.path.join(), os.path.exists()).
#
#      * Get file information:- size, stats, etc. (os.stat()).
#
#      * List files/directories:- view contents (os.listdir()).
#
#
# 23. What are the challenges associated with memory management in Python?
#
#     * Garbage Collection Overhead:- Python uses automatic garbage collection, but frequent collection can slow down performance.
#
#     * Memory Leaks:- Improper handling of objects (like circular references or unused global variables) can cause memory leaks.
#
#     * High Memory Usage:- Python objects take more space compared to lower-level languages (like C).
#
#     * Fragmentation:- Memory fragmentation may occur when small objects are frequently created and destroyed.
#
#     * Large Data Handling:- Managing memory for big data structures (like lists, dictionaries, or NumPy arrays) can be difficult.
#
# ------------------
#
# 24. How do you raise an exception manually in Python?
#
#   Raising Exceptions:- Raise exceptions to indicate errors or unexpected conditions.
#
#              Example:
#
#              def divide(x, y):
#                if y == 0:
#                raise ValueError("Cannot divide by zero")
#                return x / y
#              try:
#                result = divide(10, 0)
#                except ValueError as e:
#                print(f"Error: {e}")
#
# -------------------
#
# 25. Why is it important to use multithreading in certain applications?
#
#   * Improved Performance:- One of the primary advantages of multithreading is improved performance through parallelism. Multiple threads can execute tasks simultaneously, taking advantage of multiple CPU cores.This leads to faster execution and better overall system responsiveness.
#
#    * Resource Utilization:- Multithreading enables efficient use of system resources. Different threads can work on different parts of a task,maximizing CPU utilization and preventing idle time. This is particularly beneficial in applications where there are multiple tasks that can be executed concurrently.
#
#   * Enhanced Responsiveness:- Multithreading is crucial for maintaining responsiveness in applications, especially those with graphical user interfaces (GUIs). By separating tasks into different threads, time-consuming operations (such as file I/O or network requests) can be performed in the background without freezing the user interface.
#
#   * Concurrency:- Multithreading facilitates concurrent execution of tasks, allowing different parts of a program to progress independently. This concurrency improves the efficiency of resource usage and leads to more responsive and scalable applications.
#
#   * Scalability:- Multithreading contributes to the scalability of applications. As the number of CPU cores in modern systems increases, multithreading allows software to efficiently utilize these resources, resulting in better scalability with hardware upgrades.

# %% [markdown]
# # **Practical Questions**

# %%
#1.  How can you open a file for writing in Python and write a string to it
file = open("example.txt", "w")
file.write("Hello, this is a test message!")
file.close()
file = open("example.txt", "r")
content = file.read()
file.close()
print("File content:", content)
# Out:
# File content: Hello, this is a test message!

# %%
#2.  Write a Python program to read the contents of a file and print each line
with open("sample.txt", "w") as f:
    f.write("This is line 1\n")
    f.write("This is line 2\n")
    f.write("This is line 3\n")

with open("sample.txt", "r") as f:
    for line in f:
        print(line.strip())
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
#3.  How would you handle a case where the file doesn't exist while trying to open it for reading
try:
    with open("nofile.txt", "r") as f:
        print(f.read())
except FileNotFoundError:
    print("File does not exist!")
# Out:
# File does not exist!

# %%
#4.  Write a Python script that reads from one file and writes its content to another file
with open("source.txt", "w") as f:
    f.write("This is copied content.")
with open("source.txt", "r") as src, open("destination.txt", "w") as dst:
    dst.write(src.read())
with open("destination.txt", "r") as f:
    print(f.read())
# Out:
# This is copied content.

# %%
#5.  How would you catch and handle division by zero error in Python
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Cannot divide by zero!")
# Out:
# Error: Cannot divide by zero!

# %%
#6.  Write a Python program that logs an error message to a log file when a division by zero exception occurs
import logging
logging.basicConfig(filename="error_log.log",
                    level=logging.ERROR,
                    format="%(asctime)s - %(levelname)s - %(message)s")
try:
    num1 = 10
    num2 = 0
    result = num1 / num2   # Division by zero
    print("Result:", result)

except ZeroDivisionError as e:
    print("Error occurred! Check log file for details.")
    logging.error("Division by zero error: %s", e)
# Out:
# ERROR:root:Division by zero error: division by zero
# Error occurred! Check log file for details.

# %%
#7.  How do you log information at different levels (INFO, ERROR, WARNING) in Python using the logging module
import logging
logging.basicConfig(filename = "test_new1.log", level = logging.DEBUG, format = '%(asctime)s %(levelname)s %(message)s')

logging.debug("This msg is for debugging")
logging.info("This is my info msg")
logging.warning("This is my warning msg")
logging.shutdown()
# Out:
# WARNING:root:This is my warning msg

# %%
#8.  Write a program to handle a file opening error using exception handling
try:
    # Attempt to open a file that may not exist
    file = open("nonexistent.txt", "r")
    content = file.read()
    file.close()
    print(content)
except FileNotFoundError:
    print("Error: The file does not exist!")
except IOError:
    print("Error: An input/output error occurred.")
# Out:
# Error: The file does not exist!

# %%
#9.  How can you read a file line by line and store its content in a list in Python
with open("sample.txt", "w") as f:
    f.write("This is my first line\n")
    f.write("This is my second line\n")
    f.write("This is my third line\n")
    f.write("This is my fourth line\n")
lines_list = []
with open("sample.txt", "r") as f:
    for line in f:
        lines_list.append(line.strip())
print(lines_list)
# Out:
# ['This is my first line', 'This is my second line', 'This is my third line', 'This is my fourth line']

# %%
#10. How can you append data to an existing file in Python
with open("sample.txt", "a") as f:
    f.write("This is the fifth line\n")
    f.write("This is the sixth line\n")
with open("sample.txt", "r") as f:
    content = f.read()
print(content)
# Out:
# This is my first line
# This is my second line
# This is my third line
# This is my fourth line
# This is the fifth line
# This is the sixth line

# %%
#11. Write a Python program that uses a try-except block to handle an error when attempting to access a dictionary key that doesn't exist.
my_dict = {"name": "Alice", "age": 23}
try:
    # Attempt to access a key that doesn't exist
    print("Gender:", my_dict["gender"])
except KeyError:
    print("Error: The key does not exist in the dictionary.")
# Out:
# Error: The key does not exist in the dictionary.

# %%
#12. Write a program that demonstrates using multiple except blocks to handle different types of exceptions
try:
    num1 = int(input("Enter numerator: "))
    num2 = int(input("Enter denominator: "))
    result = num1 / num2
    print("Result:", result)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed!")
except ValueError:
    print("Error: Invalid input! Please enter numbers only.")
# Out:
# Enter numerator: 2
# Enter denominator: 0
# Error: Division by zero is not allowed!

# %%
#13. How would you check if a file exists before attempting to read it in Python
import os
filename = "sample.txt"
if os.path.exists(filename):
    with open(filename, "r") as f:
        content = f.read()
    print("File content:\n", content)
else:
    print("Error: File does not exist!")
# Out:
# File content:
#  This is my first line
# This is my second line
# This is my third line
# This is my fourth line
# This is the fifth line
# This is the sixth line

# %%
#14. Write a program that uses the logging module to log both informational and error messages
import logging
logging.basicConfig(filename="app.log",
                    level=logging.DEBUG,
                    format="%(asctime)s - %(levelname)s - %(message)s")
logging.info("Program started successfully.")
try:
    x = 10 / 0
except ZeroDivisionError as e:
    logging.error("An error occurred: %s", e)
print("Logging complete. Check 'app.log' file.")
# Out:
# ERROR:root:An error occurred: division by zero
# Logging complete. Check 'app.log' file.

# %%
#15. Write a Python program that prints the content of a file and handles the case when the file is empty
filename = "empty_file.txt"
with open(filename, "w") as f:
    pass
with open(filename, "r") as f:
    content = f.read()
if content:
    print("File content:\n", content)
else:
    print("The file is empty.")
# Out:
# The file is empty.

# %%
#16. Demonstrate how to use memory profiling to check the memory usage of a small program
# !pip install memory-profiler
from memory_profiler import memory_usage
def create_list():
    my_list = [i for i in range(100000)]  # create a large list
    return my_list
mem_usage = memory_usage(create_list)
print("Memory usage (in MiB) at different points:", mem_usage)
# Out:
# Collecting memory-profiler
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from memory-profiler) (5.9.5)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory-profiler
# Successfully installed memory-profiler-0.61.0
# Memory usage (in MiB) at different points: [120.9453125, 120.9453125, 121.3984375, 121.3984375, 121.3984375, 121.3984375, 121.3984375, 121.3984375, 120.3984375, 120.3984375]

# %%
#17. Write a Python program to create and write a list of numbers to a file, one number per line
numbers = [10, 20, 30, 40, 50]
with open("numbers.txt", "w") as f:
    for num in numbers:
        f.write(str(num) + "\n")
with open("numbers.txt", "r") as f:
    content = f.read()
print("File content:\n", content)
# Out:
# File content:
#  10
# 20
# 30
# 40
# 50

# %%
#18. How would you implement a basic logging setup that logs to a file with rotation after 1MB
import logging
from logging.handlers import RotatingFileHandler

# Create a logger
logger = logging.getLogger("MyLogger")
logger.setLevel(logging.DEBUG)

# Create a rotating file handler (1 MB max, keep 3 backups)
handler = RotatingFileHandler("rotating_app.log", maxBytes=1*1024*1024, backupCount=3)
formatter = logging.Formatter("%(asctime)s - %(levelname)s - %(message)s")
handler.setFormatter(formatter)
logger.addHandler(handler)

# Log some messages
for i in range(1000):
    logger.info(f"Logging info message {i+1}")

print("Logging complete. Check 'rotating_app.log' file.")
# Out:
# INFO:MyLogger:Logging info message 1
# INFO:MyLogger:Logging info message 2
# INFO:MyLogger:Logging info message 3
# INFO:MyLogger:Logging info message 4
# INFO:MyLogger:Logging info message 5
# INFO:MyLogger:Logging info message 6
# INFO:MyLogger:Logging info message 7
# INFO:MyLogger:Logging info message 8
# INFO:MyLogger:Logging info message 9
# INFO:MyLogger:Logging info message 10
# INFO:MyLogger:Logging info message 11
# INFO:MyLogger:Logging info message 12
# INFO:MyLogger:Logging info message 13
# INFO:MyLogger:Logging info message 14
# INFO:MyLogger:Logging info message 15
# INFO:MyLogger:Logging info message 16
# INFO:MyLogger:Logging info message 17
# INFO:MyLogger:Logging info message 18
# INFO:MyLogger:Logging info message 19
# INFO:MyLogger:Logging info message 20
# INFO:MyLogger:Logging info message 21
# INFO:MyLogger:Logging info message 22
# INFO:MyLogger:Logging info message 23
# INFO:MyLogger:Logging info message 24
# INFO:MyLogger:Logging info message 25
# INFO:MyLogger:Logging info message 26
# INFO:MyLogger:Logging info message 27
# INFO:MyLogger:Logging info message 28
# INFO:MyLogger:Logging info message 29
# INFO:MyLogger:Logging info message 30
# INFO:MyLogger:Logging info message 31
# INFO:MyLogger:Logging info message 32
# INFO:MyLogger:Logging info message 33
# INFO:MyLogger:Logging info message 34
# INFO:MyLogger:Logging info message 35
# INFO:MyLogger:Logging info message 36
# INFO:MyLogger:Logging info message 37
# INFO:MyLogger:Logging info message 38
# INFO:MyLogger:Logging info message 39
# INFO:MyLogger:Logging info message 40
# INFO:MyLogger:Logging info message 41
# INFO:MyLogger:Logging info message 42
# INFO:MyLogger:Logging info message 43
# INFO:MyLogger:Logging info message 44
# INFO:MyLogger:Logging info message 45
# INFO:MyLogger:Logging info message 46
# INFO:MyLogger:Logging info message 47
# INFO:MyLogger:Logging info message 48
# INFO:MyLogger:Logging info message 49
# INFO:MyLogger:Logging info message 50
# INFO:MyLogger:Logging info message 51
# INFO:MyLogger:Logging info message 52
# INFO:MyLogger:Logging info message 53
# INFO:MyLogger:Logging info message 54
# INFO:MyLogger:Logging info message 55
# INFO:MyLogger:Logging info message 56
# INFO:MyLogger:Logging info message 57
# INFO:MyLogger:Logging info message 58
# INFO:MyLogger:Logging info message 59
# INFO:MyLogger:Logging info message 60
# INFO:MyLogger:Logging info message 61
# INFO:MyLogger:Logging info message 62
# INFO:MyLogger:Logging info message 63
# INFO:MyLogger:Logging info message 64
# INFO:MyLogger:Logging info message 65
# INFO:MyLogger:Logging info message 66
# INFO:MyLogger:Logging info message 67
# INFO:MyLogger:Logging info message 68
# INFO:MyLogger:Logging info message 69
# INFO:MyLogger:Logging info message 70
# INFO:MyLogger:Logging info message 71
# INFO:MyLogger:Logging info message 72
# INFO:MyLogger:Logging info message 73
# INFO:MyLogger:Logging info message 74
# INFO:MyLogger:Logging info message 75
# INFO:MyLogger:Logging info message 76
# INFO:MyLogger:Logging info message 77
# INFO:MyLogger:Logging info message 78
# INFO:MyLogger:Logging info message 79
# INFO:MyLogger:Logging info message 80
# INFO:MyLogger:Logging info message 81
# INFO:MyLogger:Logging info message 82
# INFO:MyLogger:Logging info message 83
# INFO:MyLogger:Logging info message 84
# INFO:MyLogger:Logging info message 85
# INFO:MyLogger:Logging info message 86
# INFO:MyLogger:Logging info message 87
# INFO:MyLogger:Logging info message 88
# INFO:MyLogger:Logging info message 89
# INFO:MyLogger:Logging info message 90
# INFO:MyLogger:Logging info message 91
# INFO:MyLogger:Logging info message 92
# INFO:MyLogger:Logging info message 93
# INFO:MyLogger:Logging info message 94
# INFO:MyLogger:Logging info message 95
# INFO:MyLogger:Logging info message 96
# INFO:MyLogger:Logging info message 97
# INFO:MyLogger:Logging info message 98
# INFO:MyLogger:Logging info message 99
# INFO:MyLogger:Logging info message 100
# INFO:MyLogger:Logging info message 101
# INFO:MyLogger:Logging info message 102
# INFO:MyLogger:Logging info message 103
# INFO:MyLogger:Logging info message 104
# INFO:MyLogger:Logging info message 105
# INFO:MyLogger:Logging info message 106
# INFO:MyLogger:Logging info message 107
# INFO:MyLogger:Logging info message 108
# INFO:MyLogger:Logging info message 109
# INFO:MyLogger:Logging info message 110
# INFO:MyLogger:Logging info message 111
# INFO:MyLogger:Logging info message 112
# INFO:MyLogger:Logging info message 113
# INFO:MyLogger:Logging info message 114
# INFO:MyLogger:Logging info message 115
# INFO:MyLogger:Logging info message 116
# INFO:MyLogger:Logging info message 117
# INFO:MyLogger:Logging info message 118
# INFO:MyLogger:Logging info message 119
# INFO:MyLogger:Logging info message 120
# INFO:MyLogger:Logging info message 121
# INFO:MyLogger:Logging info message 122
# INFO:MyLogger:Logging info message 123
# INFO:MyLogger:Logging info message 124
# INFO:MyLogger:Logging info message 125
# INFO:MyLogger:Logging info message 126
# INFO:MyLogger:Logging info message 127
# INFO:MyLogger:Logging info message 128
# INFO:MyLogger:Logging info message 129
# INFO:MyLogger:Logging info message 130
# INFO:MyLogger:Logging info message 131
# INFO:MyLogger:Logging info message 132
# INFO:MyLogger:Logging info message 133
# INFO:MyLogger:Logging info message 134
# INFO:MyLogger:Logging info message 135
# INFO:MyLogger:Logging info message 136
# INFO:MyLogger:Logging info message 137
# INFO:MyLogger:Logging info message 138
# INFO:MyLogger:Logging info message 139
# INFO:MyLogger:Logging info message 140
# INFO:MyLogger:Logging info message 141
# INFO:MyLogger:Logging info message 142
# INFO:MyLogger:Logging info message 143
# INFO:MyLogger:Logging info message 144
# INFO:MyLogger:Logging info message 145
# INFO:MyLogger:Logging info message 146
# INFO:MyLogger:Logging info message 147
# INFO:MyLogger:Logging info message 148
# INFO:MyLogger:Logging info message 149
# INFO:MyLogger:Logging info message 150
# INFO:MyLogger:Logging info message 151
# INFO:MyLogger:Logging info message 152
# INFO:MyLogger:Logging info message 153
# INFO:MyLogger:Logging info message 154
# INFO:MyLogger:Logging info message 155
# INFO:MyLogger:Logging info message 156
# INFO:MyLogger:Logging info message 157
# INFO:MyLogger:Logging info message 158
# INFO:MyLogger:Logging info message 159
# INFO:MyLogger:Logging info message 160
# INFO:MyLogger:Logging info message 161
# INFO:MyLogger:Logging info message 162
# INFO:MyLogger:Logging info message 163
# INFO:MyLogger:Logging info message 164
# INFO:MyLogger:Logging info message 165
# INFO:MyLogger:Logging info message 166
# INFO:MyLogger:Logging info message 167
# INFO:MyLogger:Logging info message 168
# INFO:MyLogger:Logging info message 169
# INFO:MyLogger:Logging info message 170
# INFO:MyLogger:Logging info message 171
# INFO:MyLogger:Logging info message 172
# INFO:MyLogger:Logging info message 173
# INFO:MyLogger:Logging info message 174
# INFO:MyLogger:Logging info message 175
# INFO:MyLogger:Logging info message 176
# INFO:MyLogger:Logging info message 177
# INFO:MyLogger:Logging info message 178
# INFO:MyLogger:Logging info message 179
# INFO:MyLogger:Logging info message 180
# INFO:MyLogger:Logging info message 181
# INFO:MyLogger:Logging info message 182
# INFO:MyLogger:Logging info message 183
# INFO:MyLogger:Logging info message 184
# INFO:MyLogger:Logging info message 185
# INFO:MyLogger:Logging info message 186
# INFO:MyLogger:Logging info message 187
# INFO:MyLogger:Logging info message 188
# INFO:MyLogger:Logging info message 189
# INFO:MyLogger:Logging info message 190
# INFO:MyLogger:Logging info message 191
# INFO:MyLogger:Logging info message 192
# INFO:MyLogger:Logging info message 193
# INFO:MyLogger:Logging info message 194
# INFO:MyLogger:Logging info message 195
# INFO:MyLogger:Logging info message 196
# INFO:MyLogger:Logging info message 197
# INFO:MyLogger:Logging info message 198
# INFO:MyLogger:Logging info message 199
# INFO:MyLogger:Logging info message 200
# INFO:MyLogger:Logging info message 201
# INFO:MyLogger:Logging info message 202
# INFO:MyLogger:Logging info message 203
# INFO:MyLogger:Logging info message 204
# INFO:MyLogger:Logging info message 205
# INFO:MyLogger:Logging info message 206
# INFO:MyLogger:Logging info message 207
# INFO:MyLogger:Logging info message 208
# INFO:MyLogger:Logging info message 209
# INFO:MyLogger:Logging info message 210
# INFO:MyLogger:Logging info message 211
# INFO:MyLogger:Logging info message 212
# INFO:MyLogger:Logging info message 213
# INFO:MyLogger:Logging info message 214
# INFO:MyLogger:Logging info message 215
# INFO:MyLogger:Logging info message 216
# INFO:MyLogger:Logging info message 217
# INFO:MyLogger:Logging info message 218
# INFO:MyLogger:Logging info message 219
# INFO:MyLogger:Logging info message 220
# INFO:MyLogger:Logging info message 221
# INFO:MyLogger:Logging info message 222
# INFO:MyLogger:Logging info message 223
# INFO:MyLogger:Logging info message 224
# INFO:MyLogger:Logging info message 225
# INFO:MyLogger:Logging info message 226
# INFO:MyLogger:Logging info message 227
# INFO:MyLogger:Logging info message 228
# INFO:MyLogger:Logging info message 229
# INFO:MyLogger:Logging info message 230
# INFO:MyLogger:Logging info message 231
# INFO:MyLogger:Logging info message 232
# INFO:MyLogger:Logging info message 233
# INFO:MyLogger:Logging info message 234
# INFO:MyLogger:Logging info message 235
# INFO:MyLogger:Logging info message 236
# INFO:MyLogger:Logging info message 237
# INFO:MyLogger:Logging info message 238
# INFO:MyLogger:Logging info message 239
# INFO:MyLogger:Logging info message 240
# INFO:MyLogger:Logging info message 241
# INFO:MyLogger:Logging info message 242
# INFO:MyLogger:Logging info message 243
# INFO:MyLogger:Logging info message 244
# INFO:MyLogger:Logging info message 245
# INFO:MyLogger:Logging info message 246
# INFO:MyLogger:Logging info message 247
# INFO:MyLogger:Logging info message 248
# INFO:MyLogger:Logging info message 249
# INFO:MyLogger:Logging info message 250
# INFO:MyLogger:Logging info message 251
# INFO:MyLogger:Logging info message 252
# INFO:MyLogger:Logging info message 253
# INFO:MyLogger:Logging info message 254
# INFO:MyLogger:Logging info message 255
# INFO:MyLogger:Logging info message 256
# INFO:MyLogger:Logging info message 257
# INFO:MyLogger:Logging info message 258
# INFO:MyLogger:Logging info message 259
# INFO:MyLogger:Logging info message 260
# INFO:MyLogger:Logging info message 261
# INFO:MyLogger:Logging info message 262
# INFO:MyLogger:Logging info message 263
# INFO:MyLogger:Logging info message 264
# INFO:MyLogger:Logging info message 265
# INFO:MyLogger:Logging info message 266
# INFO:MyLogger:Logging info message 267
# INFO:MyLogger:Logging info message 268
# INFO:MyLogger:Logging info message 269
# INFO:MyLogger:Logging info message 270
# INFO:MyLogger:Logging info message 271
# INFO:MyLogger:Logging info message 272
# INFO:MyLogger:Logging info message 273
# INFO:MyLogger:Logging info message 274
# INFO:MyLogger:Logging info message 275
# INFO:MyLogger:Logging info message 276
# INFO:MyLogger:Logging info message 277
# INFO:MyLogger:Logging info message 278
# INFO:MyLogger:Logging info message 279
# INFO:MyLogger:Logging info message 280
# INFO:MyLogger:Logging info message 281
# INFO:MyLogger:Logging info message 282
# INFO:MyLogger:Logging info message 283
# INFO:MyLogger:Logging info message 284
# INFO:MyLogger:Logging info message 285
# INFO:MyLogger:Logging info message 286
# INFO:MyLogger:Logging info message 287
# INFO:MyLogger:Logging info message 288
# INFO:MyLogger:Logging info message 289
# INFO:MyLogger:Logging info message 290
# INFO:MyLogger:Logging info message 291
# INFO:MyLogger:Logging info message 292
# INFO:MyLogger:Logging info message 293
# INFO:MyLogger:Logging info message 294
# INFO:MyLogger:Logging info message 295
# INFO:MyLogger:Logging info message 296
# INFO:MyLogger:Logging info message 297
# INFO:MyLogger:Logging info message 298
# INFO:MyLogger:Logging info message 299
# INFO:MyLogger:Logging info message 300
# INFO:MyLogger:Logging info message 301
# INFO:MyLogger:Logging info message 302
# INFO:MyLogger:Logging info message 303
# INFO:MyLogger:Logging info message 304
# INFO:MyLogger:Logging info message 305
# INFO:MyLogger:Logging info message 306
# INFO:MyLogger:Logging info message 307
# INFO:MyLogger:Logging info message 308
# INFO:MyLogger:Logging info message 309
# INFO:MyLogger:Logging info message 310
# INFO:MyLogger:Logging info message 311
# INFO:MyLogger:Logging info message 312
# INFO:MyLogger:Logging info message 313
# INFO:MyLogger:Logging info message 314
# INFO:MyLogger:Logging info message 315
# INFO:MyLogger:Logging info message 316
# INFO:MyLogger:Logging info message 317
# INFO:MyLogger:Logging info message 318
# INFO:MyLogger:Logging info message 319
# INFO:MyLogger:Logging info message 320
# INFO:MyLogger:Logging info message 321
# INFO:MyLogger:Logging info message 322
# INFO:MyLogger:Logging info message 323
# INFO:MyLogger:Logging info message 324
# INFO:MyLogger:Logging info message 325
# INFO:MyLogger:Logging info message 326
# INFO:MyLogger:Logging info message 327
# INFO:MyLogger:Logging info message 328
# INFO:MyLogger:Logging info message 329
# INFO:MyLogger:Logging info message 330
# INFO:MyLogger:Logging info message 331
# INFO:MyLogger:Logging info message 332
# INFO:MyLogger:Logging info message 333
# INFO:MyLogger:Logging info message 334
# INFO:MyLogger:Logging info message 335
# INFO:MyLogger:Logging info message 336
# INFO:MyLogger:Logging info message 337
# INFO:MyLogger:Logging info message 338
# INFO:MyLogger:Logging info message 339
# INFO:MyLogger:Logging info message 340
# INFO:MyLogger:Logging info message 341
# INFO:MyLogger:Logging info message 342
# INFO:MyLogger:Logging info message 343
# INFO:MyLogger:Logging info message 344
# INFO:MyLogger:Logging info message 345
# INFO:MyLogger:Logging info message 346
# INFO:MyLogger:Logging info message 347
# INFO:MyLogger:Logging info message 348
# INFO:MyLogger:Logging info message 349
# INFO:MyLogger:Logging info message 350
# INFO:MyLogger:Logging info message 351
# INFO:MyLogger:Logging info message 352
# INFO:MyLogger:Logging info message 353
# INFO:MyLogger:Logging info message 354
# INFO:MyLogger:Logging info message 355
# INFO:MyLogger:Logging info message 356
# INFO:MyLogger:Logging info message 357
# INFO:MyLogger:Logging info message 358
# INFO:MyLogger:Logging info message 359
# INFO:MyLogger:Logging info message 360
# INFO:MyLogger:Logging info message 361
# INFO:MyLogger:Logging info message 362
# INFO:MyLogger:Logging info message 363
# INFO:MyLogger:Logging info message 364
# INFO:MyLogger:Logging info message 365
# INFO:MyLogger:Logging info message 366
# INFO:MyLogger:Logging info message 367
# INFO:MyLogger:Logging info message 368
# INFO:MyLogger:Logging info message 369
# INFO:MyLogger:Logging info message 370
# INFO:MyLogger:Logging info message 371
# INFO:MyLogger:Logging info message 372
# INFO:MyLogger:Logging info message 373
# INFO:MyLogger:Logging info message 374
# INFO:MyLogger:Logging info message 375
# INFO:MyLogger:Logging info message 376
# INFO:MyLogger:Logging info message 377
# INFO:MyLogger:Logging info message 378
# INFO:MyLogger:Logging info message 379
# INFO:MyLogger:Logging info message 380
# INFO:MyLogger:Logging info message 381
# INFO:MyLogger:Logging info message 382
# INFO:MyLogger:Logging info message 383
# INFO:MyLogger:Logging info message 384
# INFO:MyLogger:Logging info message 385
# INFO:MyLogger:Logging info message 386
# INFO:MyLogger:Logging info message 387
# INFO:MyLogger:Logging info message 388
# INFO:MyLogger:Logging info message 389
# INFO:MyLogger:Logging info message 390
# INFO:MyLogger:Logging info message 391
# INFO:MyLogger:Logging info message 392
# INFO:MyLogger:Logging info message 393
# INFO:MyLogger:Logging info message 394
# INFO:MyLogger:Logging info message 395
# INFO:MyLogger:Logging info message 396
# INFO:MyLogger:Logging info message 397
# INFO:MyLogger:Logging info message 398
# INFO:MyLogger:Logging info message 399
# INFO:MyLogger:Logging info message 400
# INFO:MyLogger:Logging info message 401
# INFO:MyLogger:Logging info message 402
# INFO:MyLogger:Logging info message 403
# INFO:MyLogger:Logging info message 404
# INFO:MyLogger:Logging info message 405
# INFO:MyLogger:Logging info message 406
# INFO:MyLogger:Logging info message 407
# INFO:MyLogger:Logging info message 408
# INFO:MyLogger:Logging info message 409
# INFO:MyLogger:Logging info message 410
# INFO:MyLogger:Logging info message 411
# INFO:MyLogger:Logging info message 412
# INFO:MyLogger:Logging info message 413
# INFO:MyLogger:Logging info message 414
# INFO:MyLogger:Logging info message 415
# INFO:MyLogger:Logging info message 416
# INFO:MyLogger:Logging info message 417
# INFO:MyLogger:Logging info message 418
# INFO:MyLogger:Logging info message 419
# INFO:MyLogger:Logging info message 420
# INFO:MyLogger:Logging info message 421
# INFO:MyLogger:Logging info message 422
# INFO:MyLogger:Logging info message 423
# INFO:MyLogger:Logging info message 424
# INFO:MyLogger:Logging info message 425
# INFO:MyLogger:Logging info message 426
# INFO:MyLogger:Logging info message 427
# INFO:MyLogger:Logging info message 428
# INFO:MyLogger:Logging info message 429
# INFO:MyLogger:Logging info message 430
# INFO:MyLogger:Logging info message 431
# INFO:MyLogger:Logging info message 432
# INFO:MyLogger:Logging info message 433
# INFO:MyLogger:Logging info message 434
# INFO:MyLogger:Logging info message 435
# INFO:MyLogger:Logging info message 436
# INFO:MyLogger:Logging info message 437
# INFO:MyLogger:Logging info message 438
# INFO:MyLogger:Logging info message 439
# INFO:MyLogger:Logging info message 440
# INFO:MyLogger:Logging info message 441
# INFO:MyLogger:Logging info message 442
# INFO:MyLogger:Logging info message 443
# INFO:MyLogger:Logging info message 444
# INFO:MyLogger:Logging info message 445
# INFO:MyLogger:Logging info message 446
# INFO:MyLogger:Logging info message 447
# INFO:MyLogger:Logging info message 448
# INFO:MyLogger:Logging info message 449
# INFO:MyLogger:Logging info message 450
# INFO:MyLogger:Logging info message 451
# INFO:MyLogger:Logging info message 452
# INFO:MyLogger:Logging info message 453
# INFO:MyLogger:Logging info message 454
# INFO:MyLogger:Logging info message 455
# INFO:MyLogger:Logging info message 456
# INFO:MyLogger:Logging info message 457
# INFO:MyLogger:Logging info message 458
# INFO:MyLogger:Logging info message 459
# INFO:MyLogger:Logging info message 460
# INFO:MyLogger:Logging info message 461
# INFO:MyLogger:Logging info message 462
# INFO:MyLogger:Logging info message 463
# INFO:MyLogger:Logging info message 464
# INFO:MyLogger:Logging info message 465
# INFO:MyLogger:Logging info message 466
# INFO:MyLogger:Logging info message 467
# INFO:MyLogger:Logging info message 468
# INFO:MyLogger:Logging info message 469
# INFO:MyLogger:Logging info message 470
# INFO:MyLogger:Logging info message 471
# INFO:MyLogger:Logging info message 472
# INFO:MyLogger:Logging info message 473
# INFO:MyLogger:Logging info message 474
# INFO:MyLogger:Logging info message 475
# INFO:MyLogger:Logging info message 476
# INFO:MyLogger:Logging info message 477
# INFO:MyLogger:Logging info message 478
# INFO:MyLogger:Logging info message 479
# INFO:MyLogger:Logging info message 480
# INFO:MyLogger:Logging info message 481
# INFO:MyLogger:Logging info message 482
# INFO:MyLogger:Logging info message 483
# INFO:MyLogger:Logging info message 484
# INFO:MyLogger:Logging info message 485
# INFO:MyLogger:Logging info message 486
# INFO:MyLogger:Logging info message 487
# INFO:MyLogger:Logging info message 488
# INFO:MyLogger:Logging info message 489
# INFO:MyLogger:Logging info message 490
# INFO:MyLogger:Logging info message 491
# INFO:MyLogger:Logging info message 492
# INFO:MyLogger:Logging info message 493
# INFO:MyLogger:Logging info message 494
# INFO:MyLogger:Logging info message 495
# INFO:MyLogger:Logging info message 496
# INFO:MyLogger:Logging info message 497
# INFO:MyLogger:Logging info message 498
# INFO:MyLogger:Logging info message 499
# INFO:MyLogger:Logging info message 500
# INFO:MyLogger:Logging info message 501
# INFO:MyLogger:Logging info message 502
# INFO:MyLogger:Logging info message 503
# INFO:MyLogger:Logging info message 504
# INFO:MyLogger:Logging info message 505
# INFO:MyLogger:Logging info message 506
# INFO:MyLogger:Logging info message 507
# INFO:MyLogger:Logging info message 508
# INFO:MyLogger:Logging info message 509
# INFO:MyLogger:Logging info message 510
# INFO:MyLogger:Logging info message 511
# INFO:MyLogger:Logging info message 512
# INFO:MyLogger:Logging info message 513
# INFO:MyLogger:Logging info message 514
# INFO:MyLogger:Logging info message 515
# INFO:MyLogger:Logging info message 516
# INFO:MyLogger:Logging info message 517
# INFO:MyLogger:Logging info message 518
# INFO:MyLogger:Logging info message 519
# INFO:MyLogger:Logging info message 520
# INFO:MyLogger:Logging info message 521
# INFO:MyLogger:Logging info message 522
# INFO:MyLogger:Logging info message 523
# INFO:MyLogger:Logging info message 524
# INFO:MyLogger:Logging info message 525
# INFO:MyLogger:Logging info message 526
# INFO:MyLogger:Logging info message 527
# INFO:MyLogger:Logging info message 528
# INFO:MyLogger:Logging info message 529
# INFO:MyLogger:Logging info message 530
# INFO:MyLogger:Logging info message 531
# INFO:MyLogger:Logging info message 532
# INFO:MyLogger:Logging info message 533
# INFO:MyLogger:Logging info message 534
# INFO:MyLogger:Logging info message 535
# INFO:MyLogger:Logging info message 536
# INFO:MyLogger:Logging info message 537
# INFO:MyLogger:Logging info message 538
# INFO:MyLogger:Logging info message 539
# INFO:MyLogger:Logging info message 540
# INFO:MyLogger:Logging info message 541
# INFO:MyLogger:Logging info message 542
# INFO:MyLogger:Logging info message 543
# INFO:MyLogger:Logging info message 544
# INFO:MyLogger:Logging info message 545
# INFO:MyLogger:Logging info message 546
# INFO:MyLogger:Logging info message 547
# INFO:MyLogger:Logging info message 548
# INFO:MyLogger:Logging info message 549
# INFO:MyLogger:Logging info message 550
# INFO:MyLogger:Logging info message 551
# INFO:MyLogger:Logging info message 552
# INFO:MyLogger:Logging info message 553
# INFO:MyLogger:Logging info message 554
# INFO:MyLogger:Logging info message 555
# INFO:MyLogger:Logging info message 556
# INFO:MyLogger:Logging info message 557
# INFO:MyLogger:Logging info message 558
# INFO:MyLogger:Logging info message 559
# INFO:MyLogger:Logging info message 560
# INFO:MyLogger:Logging info message 561
# INFO:MyLogger:Logging info message 562
# INFO:MyLogger:Logging info message 563
# INFO:MyLogger:Logging info message 564
# INFO:MyLogger:Logging info message 565
# INFO:MyLogger:Logging info message 566
# INFO:MyLogger:Logging info message 567
# INFO:MyLogger:Logging info message 568
# INFO:MyLogger:Logging info message 569
# INFO:MyLogger:Logging info message 570
# INFO:MyLogger:Logging info message 571
# INFO:MyLogger:Logging info message 572
# INFO:MyLogger:Logging info message 573
# INFO:MyLogger:Logging info message 574
# INFO:MyLogger:Logging info message 575
# INFO:MyLogger:Logging info message 576
# INFO:MyLogger:Logging info message 577
# INFO:MyLogger:Logging info message 578
# INFO:MyLogger:Logging info message 579
# INFO:MyLogger:Logging info message 580
# INFO:MyLogger:Logging info message 581
# INFO:MyLogger:Logging info message 582
# INFO:MyLogger:Logging info message 583
# INFO:MyLogger:Logging info message 584
# INFO:MyLogger:Logging info message 585
# INFO:MyLogger:Logging info message 586
# INFO:MyLogger:Logging info message 587
# INFO:MyLogger:Logging info message 588
# INFO:MyLogger:Logging info message 589
# INFO:MyLogger:Logging info message 590
# INFO:MyLogger:Logging info message 591
# INFO:MyLogger:Logging info message 592
# INFO:MyLogger:Logging info message 593
# INFO:MyLogger:Logging info message 594
# INFO:MyLogger:Logging info message 595
# INFO:MyLogger:Logging info message 596
# INFO:MyLogger:Logging info message 597
# INFO:MyLogger:Logging info message 598
# INFO:MyLogger:Logging info message 599
# INFO:MyLogger:Logging info message 600
# INFO:MyLogger:Logging info message 601
# INFO:MyLogger:Logging info message 602
# INFO:MyLogger:Logging info message 603
# INFO:MyLogger:Logging info message 604
# INFO:MyLogger:Logging info message 605
# INFO:MyLogger:Logging info message 606
# INFO:MyLogger:Logging info message 607
# INFO:MyLogger:Logging info message 608
# INFO:MyLogger:Logging info message 609
# INFO:MyLogger:Logging info message 610
# INFO:MyLogger:Logging info message 611
# INFO:MyLogger:Logging info message 612
# INFO:MyLogger:Logging info message 613
# INFO:MyLogger:Logging info message 614
# INFO:MyLogger:Logging info message 615
# INFO:MyLogger:Logging info message 616
# INFO:MyLogger:Logging info message 617
# INFO:MyLogger:Logging info message 618
# INFO:MyLogger:Logging info message 619
# INFO:MyLogger:Logging info message 620
# INFO:MyLogger:Logging info message 621
# INFO:MyLogger:Logging info message 622
# INFO:MyLogger:Logging info message 623
# INFO:MyLogger:Logging info message 624
# INFO:MyLogger:Logging info message 625
# INFO:MyLogger:Logging info message 626
# INFO:MyLogger:Logging info message 627
# INFO:MyLogger:Logging info message 628
# INFO:MyLogger:Logging info message 629
# INFO:MyLogger:Logging info message 630
# INFO:MyLogger:Logging info message 631
# INFO:MyLogger:Logging info message 632
# INFO:MyLogger:Logging info message 633
# INFO:MyLogger:Logging info message 634
# INFO:MyLogger:Logging info message 635
# INFO:MyLogger:Logging info message 636
# INFO:MyLogger:Logging info message 637
# INFO:MyLogger:Logging info message 638
# INFO:MyLogger:Logging info message 639
# INFO:MyLogger:Logging info message 640
# INFO:MyLogger:Logging info message 641
# INFO:MyLogger:Logging info message 642
# INFO:MyLogger:Logging info message 643
# INFO:MyLogger:Logging info message 644
# INFO:MyLogger:Logging info message 645
# INFO:MyLogger:Logging info message 646
# INFO:MyLogger:Logging info message 647
# INFO:MyLogger:Logging info message 648
# INFO:MyLogger:Logging info message 649
# INFO:MyLogger:Logging info message 650
# INFO:MyLogger:Logging info message 651
# INFO:MyLogger:Logging info message 652
# INFO:MyLogger:Logging info message 653
# INFO:MyLogger:Logging info message 654
# INFO:MyLogger:Logging info message 655
# INFO:MyLogger:Logging info message 656
# INFO:MyLogger:Logging info message 657
# INFO:MyLogger:Logging info message 658
# INFO:MyLogger:Logging info message 659
# INFO:MyLogger:Logging info message 660
# INFO:MyLogger:Logging info message 661
# INFO:MyLogger:Logging info message 662
# INFO:MyLogger:Logging info message 663
# INFO:MyLogger:Logging info message 664
# INFO:MyLogger:Logging info message 665
# INFO:MyLogger:Logging info message 666
# INFO:MyLogger:Logging info message 667
# INFO:MyLogger:Logging info message 668
# INFO:MyLogger:Logging info message 669
# INFO:MyLogger:Logging info message 670
# INFO:MyLogger:Logging info message 671
# INFO:MyLogger:Logging info message 672
# INFO:MyLogger:Logging info message 673
# INFO:MyLogger:Logging info message 674
# INFO:MyLogger:Logging info message 675
# INFO:MyLogger:Logging info message 676
# INFO:MyLogger:Logging info message 677
# INFO:MyLogger:Logging info message 678
# INFO:MyLogger:Logging info message 679
# INFO:MyLogger:Logging info message 680
# INFO:MyLogger:Logging info message 681
# INFO:MyLogger:Logging info message 682
# INFO:MyLogger:Logging info message 683
# INFO:MyLogger:Logging info message 684
# INFO:MyLogger:Logging info message 685
# INFO:MyLogger:Logging info message 686
# INFO:MyLogger:Logging info message 687
# INFO:MyLogger:Logging info message 688
# INFO:MyLogger:Logging info message 689
# INFO:MyLogger:Logging info message 690
# INFO:MyLogger:Logging info message 691
# INFO:MyLogger:Logging info message 692
# INFO:MyLogger:Logging info message 693
# INFO:MyLogger:Logging info message 694
# INFO:MyLogger:Logging info message 695
# INFO:MyLogger:Logging info message 696
# INFO:MyLogger:Logging info message 697
# INFO:MyLogger:Logging info message 698
# INFO:MyLogger:Logging info message 699
# INFO:MyLogger:Logging info message 700
# INFO:MyLogger:Logging info message 701
# INFO:MyLogger:Logging info message 702
# INFO:MyLogger:Logging info message 703
# INFO:MyLogger:Logging info message 704
# INFO:MyLogger:Logging info message 705
# INFO:MyLogger:Logging info message 706
# INFO:MyLogger:Logging info message 707
# INFO:MyLogger:Logging info message 708
# INFO:MyLogger:Logging info message 709
# INFO:MyLogger:Logging info message 710
# INFO:MyLogger:Logging info message 711
# INFO:MyLogger:Logging info message 712
# INFO:MyLogger:Logging info message 713
# INFO:MyLogger:Logging info message 714
# INFO:MyLogger:Logging info message 715
# INFO:MyLogger:Logging info message 716
# INFO:MyLogger:Logging info message 717
# INFO:MyLogger:Logging info message 718
# INFO:MyLogger:Logging info message 719
# INFO:MyLogger:Logging info message 720
# INFO:MyLogger:Logging info message 721
# INFO:MyLogger:Logging info message 722
# INFO:MyLogger:Logging info message 723
# INFO:MyLogger:Logging info message 724
# INFO:MyLogger:Logging info message 725
# INFO:MyLogger:Logging info message 726
# INFO:MyLogger:Logging info message 727
# INFO:MyLogger:Logging info message 728
# INFO:MyLogger:Logging info message 729
# INFO:MyLogger:Logging info message 730
# INFO:MyLogger:Logging info message 731
# INFO:MyLogger:Logging info message 732
# INFO:MyLogger:Logging info message 733
# INFO:MyLogger:Logging info message 734
# INFO:MyLogger:Logging info message 735
# INFO:MyLogger:Logging info message 736
# INFO:MyLogger:Logging info message 737
# INFO:MyLogger:Logging info message 738
# INFO:MyLogger:Logging info message 739
# INFO:MyLogger:Logging info message 740
# INFO:MyLogger:Logging info message 741
# INFO:MyLogger:Logging info message 742
# INFO:MyLogger:Logging info message 743
# INFO:MyLogger:Logging info message 744
# INFO:MyLogger:Logging info message 745
# INFO:MyLogger:Logging info message 746
# INFO:MyLogger:Logging info message 747
# INFO:MyLogger:Logging info message 748
# INFO:MyLogger:Logging info message 749
# INFO:MyLogger:Logging info message 750
# INFO:MyLogger:Logging info message 751
# INFO:MyLogger:Logging info message 752
# INFO:MyLogger:Logging info message 753
# INFO:MyLogger:Logging info message 754
# INFO:MyLogger:Logging info message 755
# INFO:MyLogger:Logging info message 756
# INFO:MyLogger:Logging info message 757
# INFO:MyLogger:Logging info message 758
# INFO:MyLogger:Logging info message 759
# INFO:MyLogger:Logging info message 760
# INFO:MyLogger:Logging info message 761
# INFO:MyLogger:Logging info message 762
# INFO:MyLogger:Logging info message 763
# INFO:MyLogger:Logging info message 764
# INFO:MyLogger:Logging info message 765
# INFO:MyLogger:Logging info message 766
# INFO:MyLogger:Logging info message 767
# INFO:MyLogger:Logging info message 768
# INFO:MyLogger:Logging info message 769
# INFO:MyLogger:Logging info message 770
# INFO:MyLogger:Logging info message 771
# INFO:MyLogger:Logging info message 772
# INFO:MyLogger:Logging info message 773
# INFO:MyLogger:Logging info message 774
# INFO:MyLogger:Logging info message 775
# INFO:MyLogger:Logging info message 776
# INFO:MyLogger:Logging info message 777
# INFO:MyLogger:Logging info message 778
# INFO:MyLogger:Logging info message 779
# INFO:MyLogger:Logging info message 780
# INFO:MyLogger:Logging info message 781
# INFO:MyLogger:Logging info message 782
# INFO:MyLogger:Logging info message 783
# INFO:MyLogger:Logging info message 784
# INFO:MyLogger:Logging info message 785
# INFO:MyLogger:Logging info message 786
# INFO:MyLogger:Logging info message 787
# INFO:MyLogger:Logging info message 788
# INFO:MyLogger:Logging info message 789
# INFO:MyLogger:Logging info message 790
# INFO:MyLogger:Logging info message 791
# INFO:MyLogger:Logging info message 792
# INFO:MyLogger:Logging info message 793
# INFO:MyLogger:Logging info message 794
# INFO:MyLogger:Logging info message 795
# INFO:MyLogger:Logging info message 796
# INFO:MyLogger:Logging info message 797
# INFO:MyLogger:Logging info message 798
# INFO:MyLogger:Logging info message 799
# INFO:MyLogger:Logging info message 800
# INFO:MyLogger:Logging info message 801
# INFO:MyLogger:Logging info message 802
# INFO:MyLogger:Logging info message 803
# INFO:MyLogger:Logging info message 804
# INFO:MyLogger:Logging info message 805
# INFO:MyLogger:Logging info message 806
# INFO:MyLogger:Logging info message 807
# INFO:MyLogger:Logging info message 808
# INFO:MyLogger:Logging info message 809
# INFO:MyLogger:Logging info message 810
# INFO:MyLogger:Logging info message 811
# INFO:MyLogger:Logging info message 812
# INFO:MyLogger:Logging info message 813
# INFO:MyLogger:Logging info message 814
# INFO:MyLogger:Logging info message 815
# INFO:MyLogger:Logging info message 816
# INFO:MyLogger:Logging info message 817
# INFO:MyLogger:Logging info message 818
# INFO:MyLogger:Logging info message 819
# INFO:MyLogger:Logging info message 820
# INFO:MyLogger:Logging info message 821
# INFO:MyLogger:Logging info message 822
# INFO:MyLogger:Logging info message 823
# INFO:MyLogger:Logging info message 824
# INFO:MyLogger:Logging info message 825
# INFO:MyLogger:Logging info message 826
# INFO:MyLogger:Logging info message 827
# INFO:MyLogger:Logging info message 828
# INFO:MyLogger:Logging info message 829
# INFO:MyLogger:Logging info message 830
# INFO:MyLogger:Logging info message 831
# INFO:MyLogger:Logging info message 832
# INFO:MyLogger:Logging info message 833
# INFO:MyLogger:Logging info message 834
# INFO:MyLogger:Logging info message 835
# INFO:MyLogger:Logging info message 836
# INFO:MyLogger:Logging info message 837
# INFO:MyLogger:Logging info message 838
# INFO:MyLogger:Logging info message 839
# INFO:MyLogger:Logging info message 840
# INFO:MyLogger:Logging info message 841
# INFO:MyLogger:Logging info message 842
# INFO:MyLogger:Logging info message 843
# INFO:MyLogger:Logging info message 844
# INFO:MyLogger:Logging info message 845
# INFO:MyLogger:Logging info message 846
# INFO:MyLogger:Logging info message 847
# INFO:MyLogger:Logging info message 848
# INFO:MyLogger:Logging info message 849
# INFO:MyLogger:Logging info message 850
# INFO:MyLogger:Logging info message 851
# INFO:MyLogger:Logging info message 852
# INFO:MyLogger:Logging info message 853
# INFO:MyLogger:Logging info message 854
# INFO:MyLogger:Logging info message 855
# INFO:MyLogger:Logging info message 856
# INFO:MyLogger:Logging info message 857
# INFO:MyLogger:Logging info message 858
# INFO:MyLogger:Logging info message 859
# INFO:MyLogger:Logging info message 860
# INFO:MyLogger:Logging info message 861
# INFO:MyLogger:Logging info message 862
# INFO:MyLogger:Logging info message 863
# INFO:MyLogger:Logging info message 864
# INFO:MyLogger:Logging info message 865
# INFO:MyLogger:Logging info message 866
# INFO:MyLogger:Logging info message 867
# INFO:MyLogger:Logging info message 868
# INFO:MyLogger:Logging info message 869
# INFO:MyLogger:Logging info message 870
# INFO:MyLogger:Logging info message 871
# INFO:MyLogger:Logging info message 872
# INFO:MyLogger:Logging info message 873
# INFO:MyLogger:Logging info message 874
# INFO:MyLogger:Logging info message 875
# INFO:MyLogger:Logging info message 876
# INFO:MyLogger:Logging info message 877
# INFO:MyLogger:Logging info message 878
# INFO:MyLogger:Logging info message 879
# INFO:MyLogger:Logging info message 880
# INFO:MyLogger:Logging info message 881
# INFO:MyLogger:Logging info message 882
# INFO:MyLogger:Logging info message 883
# INFO:MyLogger:Logging info message 884
# INFO:MyLogger:Logging info message 885
# INFO:MyLogger:Logging info message 886
# INFO:MyLogger:Logging info message 887
# INFO:MyLogger:Logging info message 888
# INFO:MyLogger:Logging info message 889
# INFO:MyLogger:Logging info message 890
# INFO:MyLogger:Logging info message 891
# INFO:MyLogger:Logging info message 892
# INFO:MyLogger:Logging info message 893
# INFO:MyLogger:Logging info message 894
# INFO:MyLogger:Logging info message 895
# INFO:MyLogger:Logging info message 896
# INFO:MyLogger:Logging info message 897
# INFO:MyLogger:Logging info message 898
# INFO:MyLogger:Logging info message 899
# INFO:MyLogger:Logging info message 900
# INFO:MyLogger:Logging info message 901
# INFO:MyLogger:Logging info message 902
# INFO:MyLogger:Logging info message 903
# INFO:MyLogger:Logging info message 904
# INFO:MyLogger:Logging info message 905
# INFO:MyLogger:Logging info message 906
# INFO:MyLogger:Logging info message 907
# INFO:MyLogger:Logging info message 908
# INFO:MyLogger:Logging info message 909
# INFO:MyLogger:Logging info message 910
# INFO:MyLogger:Logging info message 911
# INFO:MyLogger:Logging info message 912
# INFO:MyLogger:Logging info message 913
# INFO:MyLogger:Logging info message 914
# INFO:MyLogger:Logging info message 915
# INFO:MyLogger:Logging info message 916
# INFO:MyLogger:Logging info message 917
# INFO:MyLogger:Logging info message 918
# INFO:MyLogger:Logging info message 919
# INFO:MyLogger:Logging info message 920
# INFO:MyLogger:Logging info message 921
# INFO:MyLogger:Logging info message 922
# INFO:MyLogger:Logging info message 923
# INFO:MyLogger:Logging info message 924
# INFO:MyLogger:Logging info message 925
# INFO:MyLogger:Logging info message 926
# INFO:MyLogger:Logging info message 927
# INFO:MyLogger:Logging info message 928
# INFO:MyLogger:Logging info message 929
# INFO:MyLogger:Logging info message 930
# INFO:MyLogger:Logging info message 931
# INFO:MyLogger:Logging info message 932
# INFO:MyLogger:Logging info message 933
# INFO:MyLogger:Logging info message 934
# INFO:MyLogger:Logging info message 935
# INFO:MyLogger:Logging info message 936
# INFO:MyLogger:Logging info message 937
# INFO:MyLogger:Logging info message 938
# INFO:MyLogger:Logging info message 939
# INFO:MyLogger:Logging info message 940
# INFO:MyLogger:Logging info message 941
# INFO:MyLogger:Logging info message 942
# INFO:MyLogger:Logging info message 943
# INFO:MyLogger:Logging info message 944
# INFO:MyLogger:Logging info message 945
# INFO:MyLogger:Logging info message 946
# INFO:MyLogger:Logging info message 947
# INFO:MyLogger:Logging info message 948
# INFO:MyLogger:Logging info message 949
# INFO:MyLogger:Logging info message 950
# INFO:MyLogger:Logging info message 951
# INFO:MyLogger:Logging info message 952
# INFO:MyLogger:Logging info message 953
# INFO:MyLogger:Logging info message 954
# INFO:MyLogger:Logging info message 955
# INFO:MyLogger:Logging info message 956
# INFO:MyLogger:Logging info message 957
# INFO:MyLogger:Logging info message 958
# INFO:MyLogger:Logging info message 959
# INFO:MyLogger:Logging info message 960
# INFO:MyLogger:Logging info message 961
# INFO:MyLogger:Logging info message 962
# INFO:MyLogger:Logging info message 963
# INFO:MyLogger:Logging info message 964
# INFO:MyLogger:Logging info message 965
# INFO:MyLogger:Logging info message 966
# INFO:MyLogger:Logging info message 967
# INFO:MyLogger:Logging info message 968
# INFO:MyLogger:Logging info message 969
# INFO:MyLogger:Logging info message 970
# INFO:MyLogger:Logging info message 971
# INFO:MyLogger:Logging info message 972
# INFO:MyLogger:Logging info message 973
# INFO:MyLogger:Logging info message 974
# INFO:MyLogger:Logging info message 975
# INFO:MyLogger:Logging info message 976
# INFO:MyLogger:Logging info message 977
# INFO:MyLogger:Logging info message 978
# INFO:MyLogger:Logging info message 979
# INFO:MyLogger:Logging info message 980
# INFO:MyLogger:Logging info message 981
# INFO:MyLogger:Logging info message 982
# INFO:MyLogger:Logging info message 983
# INFO:MyLogger:Logging info message 984
# INFO:MyLogger:Logging info message 985
# INFO:MyLogger:Logging info message 986
# INFO:MyLogger:Logging info message 987
# INFO:MyLogger:Logging info message 988
# INFO:MyLogger:Logging info message 989
# INFO:MyLogger:Logging info message 990
# INFO:MyLogger:Logging info message 991
# INFO:MyLogger:Logging info message 992
# INFO:MyLogger:Logging info message 993
# INFO:MyLogger:Logging info message 994
# INFO:MyLogger:Logging info message 995
# INFO:MyLogger:Logging info message 996
# INFO:MyLogger:Logging info message 997
# INFO:MyLogger:Logging info message 998
# INFO:MyLogger:Logging info message 999
# INFO:MyLogger:Logging info message 1000
# Logging complete. Check 'rotating_app.log' file.

# %%
#19. Write a program that handles both IndexError and KeyError using a try-except block
my_list = [10, 20, 30]
my_dict = {"name": "Alice", "age": 25}
try:
    print("Access list element:", my_list[5])
    print("Access dictionary key:", my_dict["gender"])
except IndexError:
    print("Error: Tried to access an index that doesn't exist!")
except KeyError:
    print("Error: Tried to access a key that doesn't exist!")
# Out:
# Error: Tried to access an index that doesn't exist!

# %%
#20. How would you open a file and read its contents using a context manager in Python
with open("example.txt", "w") as f:
    f.write("Hello World!\nPython is fun.\nLet's read this file.")
with open("example.txt", "r") as f:
    content = f.read()
print("File content:\n", content)
# Out:
# File content:
#  Hello World!
# Python is fun.
# Let's read this file.

# %%
#21. Write a Python program that reads a file and prints the number of occurrences of a specific word
with open("story.txt", "w") as f:
    f.write("Python is fun. Learning Python is great. Python is easy to understand.")
word_to_count = "Python"
with open("story.txt", "r") as f:
    content = f.read()
count = content.count(word_to_count)
print(f"The word '{word_to_count}' appears {count} times in the file.")
# Out:
# The word 'Python' appears 3 times in the file.

# %%
#22. How can you check if a file is empty before attempting to read its contents
import os
filename = "empty_check.txt"
with open(filename, "w") as f:
    pass
if os.path.getsize(filename) == 0:
    print("The file is empty.")
else:
    with open(filename, "r") as f:
        print(f.read())
# Out:
# The file is empty.

# %%
#23.  Write a Python program that writes to a log file when an error occurs during file handling.
import logging
logging.basicConfig(filename="file_error.log",
                    level=logging.ERROR,
                    format="%(asctime)s - %(levelname)s - %(message)s")
try:
    with open("no_file.txt", "r") as f:
        content = f.read()
except FileNotFoundError as e:
    logging.error("Error occurred: %s", e)
    print("An error occurred. Check 'file_error.log' for details.")
# Out:
# ERROR:root:Error occurred: [Errno 2] No such file or directory: 'no_file.txt'
# An error occurred. Check 'file_error.log' for details.
